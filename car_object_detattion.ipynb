# %% [markdown]
# <a href="https://colab.research.google.com/github/KAYO-ult/1st-SEMESTER/blob/main/car_object_detattion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 25.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from ultralytics import YOLO
import cv2
import kagglehub
import os

from ultralytics import YOLO
import cv2

# Load a pre-trained YOLOv8 model.
# The 'n' stands for nano, which is a small and fast version.
model = YOLO('yolov8n.pt')

# Define the classes you are interested in.
# The COCO dataset has a class for 'car' which is ID 2.
car_class_id = 2

# Load an image from file.
# Replace 'path/to/your/image.jpg' with the actual path to your image file.

# Download latest version
image_path = kagglehub.dataset_download("sshikamaru/car-object-detection")# Dummy image path for demonstration
image = cv2.imread(image_path)

print("Path to dataset files:", image_path)
# List files in the 'data' subdirectory
data_files = os.listdir(os.path.join(image_path, 'data'))
print("Files in the 'data' directory:", data_files)



if image is None:
    print(f"Error: Could not load image from {data_files}")
else:
    # Run inference on the image.
    # We specify the class we want to detect.
    results = model(image, classes=[car_class_id])

    # Process the results.
    for r in results:
        # Get the bounding boxes for the detected objects.
        boxes = r.boxes

        for box in boxes:
            # Get the coordinates, confidence, and class ID of the bounding box.
            x1, y1, x2, y2 = box.xyxy[0].int().tolist()
            confidence = box.conf[0].item()
            class_id = box.cls[0].item()

            # Check if the detected object is a car (class ID 2) and has high confidence.
            if class_id == car_class_id and confidence > 0.5:
                # Draw the bounding box and label on the image.
                cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
                label = f'Car: {confidence:.2f}'
                cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Display the result.
    cv2.imshow('Car Detection', image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# Note: For video detection, you would replace the image loading and display
# loop with a video capture loop.
# Out:
# Path to dataset files: /kaggle/input/car-object-detection
# Files in the 'data' directory: ['sample_submission.csv', 'testing_images', 'train_solution_bounding_boxes (1).csv', 'training_images']
# Error: Could not load image from ['sample_submission.csv', 'testing_images', 'train_solution_bounding_boxes (1).csv', 'training_images']

# %%
# YOLOv10 Vehicle Detection & Tracking (video-focused) in Google Colab

# 1. Install YOLOv10 (official) and dependencies
# !pip install -q git+https://github.com/THU-MIG/yolov10.git
# !pip install ultralytics opencv-python

from ultralytics import YOLOv10
import os
from google.colab import drive

# 2. (Optional) Mount Google Drive for dataset & video storage
# drive.mount('/content/drive')

# 3. Download pretrained YOLOv10l weights
# !mkdir -p weights
# !wget -q -P weights https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt

# 4. Prepare your dataset
# Organize as:
# datasets/vehicles/
# ├── images/train/
# ├── images/val/
# └── labels/train/, labels/val/

# If you store on Drive, unzip or copy accordingly.

# 5. Create data.yaml configuration
data_yaml = """\
path: datasets/vehicles
train: images/train
val: images/val
test: images/test

names:
  0: car
  1: truck
  2: motorcycle
  3: bus
"""
with open("data.yaml", "w") as f:
    f.write(data_yaml)

# 6. Load YOLOv10 model (large variant)
model = YOLOv10("weights/yolov10l.pt")

# 7. Train on your dataset
model.train(
    data="data.yaml",
    epochs=50,          # increase if needed
    imgsz=1280,
    batch=16,
    device=0,
    workers=8,
    name="yolov10l-vehicles",
    project="runs/vehicles"
)

# 8. Validate model
model.val(data="data.yaml")

# 9. Inference on a traffic video
video_path = "traffic.mp4"  # Update to your actual video file path
results = model.predict(
    source=video_path,
    conf=0.25,
    save=True,
    show=False
)
print("✅ Detection complete. See output under runs/detect/predict/")

# 10. (Optional) Track vehicles across frames using ByteTrack
results = model.track(
    source=video_path,
    conf=0.25,
    tracker="bytetrack.yaml",  # Requires tracking YAML config
    save=True,
    show=False
)
print("✅ Tracking complete. See output under runs/track/predict/")
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-1758441443.py in <cell line: 0>()
#       5 get_ipython().system('pip install ultralytics opencv-python')
#       6
# ----> 7 from ultralytics import YOLOv10
#       8 import os
#       9 from google.colab import drive
#
# ImportError: cannot import name 'YOLOv10' from 'ultralytics' (/usr/local/lib/python3.12/dist-packages/ultralytics/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ...

# %%
# !git clone https://github.com/PrathamMMallya/Dynamic-Traffic-Control-YOLOv10.git
# Out:
# Cloning into 'Dynamic-Traffic-Control-YOLOv10'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 38.28 MiB | 26.38 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
pip install opencv-python numpy ultralytics cvzone
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for cvzone: filename=cvzone-1.6.1-py3-none-any.whl size=26298 sha256=f5bf97ce8357c58c57612883413c1178040044d0c78eae2acc32379fcdbf72df
#   Stored in directory: /root/.cache/pip/wheels/5d/21/e8/3147ae88d44e27f06e0175d337a7673c70fb957202cbbe2034
# Successfully built cvzone
# ...

# %%
# ===========================
# 1. Setup Environment
# ===========================
# !pip install ultralytics kaggle -q

import os

# Make kaggle folder
os.makedirs("/content/kaggle", exist_ok=True)

# 🔑 Upload your Kaggle API key (kaggle.json) from your Kaggle account
# Go to Kaggle > Account > Create API Token, then upload the file
from google.colab import files
uploaded = files.upload()

# Move kaggle.json to the right place
# !mv kaggle.json /root/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json


# ===========================
# 2. Download Dataset from Kaggle
# ===========================
# !kaggle datasets download -d alirezachahardoli/vehicle-detection -p /content/datasets --unzip

# Check structure
# !ls /content/datasets/vehicle-detection


# ===========================
# 3. Create data.yaml Config
# ===========================
data_yaml = """
path: /content/datasets/vehicle-detection
train: images/train
val: images/val

names:
  0: car
  1: truck
  2: motorcycle
  3: bus
"""

with open("data.yaml", "w") as f:
    f.write(data_yaml)

print("✅ data.yaml created!")
# !cat data.yaml


# ===========================
# 4. Train YOLOv10
# ===========================
from ultralytics import YOLO

# Load YOLOv10 model (large version for accuracy)
model = YOLO("yolov10l.pt")

# Train the model
model.train(
    data="data.yaml",
    epochs=50,
    imgsz=1280,
    batch=8,
    workers=2,
    device=0  # GPU
)


# ===========================
# 5. Run Inference on a Video
# ===========================
# Example: upload a video from your system
uploaded_video = files.upload()

video_path = list(uploaded_video.keys())[0]

# Run detection
results = model.predict(
    source=video_path,
    conf=0.5,     # confidence threshold
    save=True,    # saves the output video
    project="runs/detect",
    name="vehicledemo"
)

print("✅ Inference done! Check output in /content/output")

# ===========================
# 6. Display the Processed Video
# ===========================
import cv2
from google.colab.patches import cv2_imshow

output_path = "/content/output" + video_path

# Extract and show first frame of the output
cap = cv2.VideoCapture(output_path)
ret, frame = cap.read()
if ret:
    cv2_imshow(frame)
cap.release()
# Out:
#      <input type="file" id="files-af173c8f-2088-4a41-96f1-75f9045340ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af173c8f-2088-4a41-96f1-75f9045340ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
